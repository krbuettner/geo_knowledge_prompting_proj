# %% [markdown]
# ### Script to Easily Parse Results

# %% [markdown]
# ### Imports

# %%
import os
import numpy as np

# %% [markdown]
# ### Key Variables to Determine WHich Files to Parse

# %%
MODEL_VERS = 'rn50_ep100' # 'vit_b16_ep100_ctxv1' or 'rn50_ep100'
VERS_OF_INFERENCE = 'Peru' # For DollarStreet: src, tgt, as, am, af - which logs to look at


LIST_OF_TEST_CASES = ['dollarstreet_default',                                   # which subfolders to look at 
                      'tgt_llm_ensemble_dollarstreet',
                      'tgt_in_country_ensemble_dollarstreet',
                      'tgt_llm_and_in_country_ensemble_dollarstreet'] 

#LIST_OF_TEST_CASES = [
#    'am_dollarstreet_default',
#    'tgt_llm_and_in_country_ensemble_dollarstreet',
#    'am_tgt_in_country_ensemble_dollarstreet',
#    'am_tgt_llm_ensemble_dollarstreet',
#    'am_tgt_llm_and_in_country_ensemble_dollarstreet'
#]
#LIST_OF_TEST_CASES = ['dollarstreet_default',                                   # which subfolders to look at 
#                      'all_llm_ensemble_dollarstreet',                          # CoOp/CoCoOp/KgCoOp belong to default
#                      'src_llm_ensemble_dollarstreet', 
#                      'tgt_llm_ensemble_dollarstreet',
#                      'all_in_country_ensemble_dollarstreet',
#                      'src_in_country_ensemble_dollarstreet', 
#                      'tgt_in_country_ensemble_dollarstreet',
#                      'all_llm_and_in_country_ensemble_dollarstreet',
#                      'src_llm_and_in_country_ensemble_dollarstreet', 
#                      'tgt_llm_and_in_country_ensemble_dollarstreet'] 
#LIST_OF_TEST_CASES = ['chat_all_llm_ensemble_dollarstreet',                          # CoOp/CoCoOp/KgCoOp belong to default
#                      'chat_src_llm_ensemble_dollarstreet', 
#                      'chat_tgt_llm_ensemble_dollarstreet',
#                      'chat_all_llm_and_in_country_ensemble_dollarstreet',
#                      'chat_src_llm_and_in_country_ensemble_dollarstreet', 
#                      'chat_tgt_llm_and_in_country_ensemble_dollarstreet']
#LIST_OF_TEST_CASES = ['dollarstreet_default',                                   # which subfolders to look at 
#                      'af_llm_ensemble_dollarstreet',                          # CoOp/CoCoOp/KgCoOp belong to default
#                      'am_llm_ensemble_dollarstreet', 
#                      'as_llm_ensemble_dollarstreet',
#                      'af_in_country_ensemble_dollarstreet',
#                      'am_in_country_ensemble_dollarstreet', 
#                      'as_in_country_ensemble_dollarstreet',
#                      'af_llm_and_in_country_ensemble_dollarstreet',
#                      'am_llm_and_in_country_ensemble_dollarstreet', 
#                      'as_llm_and_in_country_ensemble_dollarstreet'
#                    ]

#LIST_OF_TEST_CASES = [
#    'subset_tgt_dollarstreet',
#    'tgt_llm_and_in_country_ensemble_dollarstreet',
#    'dollarstreet_default'
#]
#LIST_OF_TEST_CASES = ['geonet',                                   # which subfolders to look at 
#                      'tgt_in_country_ensemble_geonet',                          # CoOp/CoCoOp/KgCoOp belong to default
#                      'tgt_llm_ensemble_geonet', 
#                      'geonet_in_country_llm_desc',
#                     ]

ROOT_PATH_REPO = '/afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/'
SUBFOLDER_START = 'output/all/'
#SUBFOLDER_START = 'output/evaluation/geonet_llm_ensemble/CoOp_Contrastive_Datt/vit_b16_ep100_ctxv1_16shots/nctx4_cscFalse_ctpend/geonet_llm_ensemble/TRAIN_usa/TEST_asia'
#EXTRA_APPEND = 'GOLD_RESULTS_11_2_2nd_trial/'
#EXTRA_APPEND = 'MAIN_RESULTS_10_21_23/'
EXTRA_APPEND = ''

# %%
# This determines which results we are looking at 
if VERS_OF_INFERENCE == "src":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'train_all/' + EXTRA_APPEND 
elif VERS_OF_INFERENCE == "as":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/' + EXTRA_APPEND + 'full_as_dollarstreet/' 
elif VERS_OF_INFERENCE == "am":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START +'test_all/'  + EXTRA_APPEND + 'full_am_dollarstreet/'
elif VERS_OF_INFERENCE == "af":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_af_dollarstreet/'
elif VERS_OF_INFERENCE == "eu":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_eu_dollarstreet/'
elif VERS_OF_INFERENCE == "spec_src":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'train_all/'  + EXTRA_APPEND 
elif VERS_OF_INFERENCE == "spec_tgt":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/am_'  + EXTRA_APPEND + 'full_tgt_dollarstreet/'
elif VERS_OF_INFERENCE == "sub":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'subset_tgt_dollarstreet/'
elif VERS_OF_INFERENCE == "high_econ":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_high_econ_dollarstreet/'
elif VERS_OF_INFERENCE == "low_econ":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_low_econ_dollarstreet/'
elif VERS_OF_INFERENCE == "medium_econ":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_medium_econ_dollarstreet/'
    
elif VERS_OF_INFERENCE == "Bolivia":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_bolivia_dollarstreet/'
elif VERS_OF_INFERENCE == "Brazil":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_brazil_dollarstreet/'
elif VERS_OF_INFERENCE == "Canada":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_canada_dollarstreet/'
elif VERS_OF_INFERENCE == "Colombia":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_colombia_dollarstreet/'
elif VERS_OF_INFERENCE == "Guatemala":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_guatemala_dollarstreet/'
elif VERS_OF_INFERENCE == "Haiti":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_haiti_dollarstreet/'
elif VERS_OF_INFERENCE == "Mexico":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_mexico_dollarstreet/'
elif VERS_OF_INFERENCE == "Peru":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_peru_dollarstreet/'
elif VERS_OF_INFERENCE == "United States":
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_unitedstates_dollarstreet/'
    
    
    
    
    
else:
    OUT_PATH = ROOT_PATH_REPO + SUBFOLDER_START + 'test_all/'  + EXTRA_APPEND + 'full_tgt_dollarstreet/'
print(OUT_PATH)
# Out:
# /afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/

# %% [markdown]
# ### Make Dictionary of Metrics

# %%
# Function to parse classwise accuracies 
def parse_line(line):
    class_id = int(line.split('* class: ')[1].split('(')[0])
    class_name = line.split('(')[1].split(')')[0]
    num_correct = int(line.split('correct: ')[1].split('\t')[0])
    total = int(line.split('total: ')[1].split('\t')[0])
    overall_acc = num_correct / total
    return class_id, class_name, num_correct, total, overall_acc

# %%
# Define a dictionary to store data from parsing logs
dict_case_and_weight_to_data = dict()

# Loop through each test case 
for case in LIST_OF_TEST_CASES:
    print(case)
    gen_path = os.path.join(OUT_PATH, case)
    
    # Define current tests to look at 
    # For DollarStreet Default, we want to look at CoOp, CoCoOp, etc. 
    # GeoKgCoOp used with ensemble options
    if case == 'am_dollarstreet_default' or case == 'dollarstreet_default' or case == 'geonet' or case == 'subset_tgt_dollarstreet':
        curr_modes = ['CoOp', 'CoCoOp', 'KgCoOp', 'GeoKgCoOp'] # change this later
    else:
        curr_modes =  ['GeoKgCoOp']

        
    # Loop through current modes
    for mode in curr_modes: 
    
        # Which weights should we gather 
        if mode == 'GeoKgCoOp':
            tests = ['shots_16_2.0', 'shots_16_4.0', 'shots_16_6.0', 'shots_16_8.0', 'shots_16_10.0'] 
        elif mode == 'KgCoOp':
            tests = ['shots_16_2.0', 'shots_16_4.0', 'shots_16_6.0', 'shots_16_8.0', 'shots_16_10.0']
        elif mode == 'CoOp' or mode == 'CoCoOp':
            tests = ['shots_16_0.0']
            if case == 'subset_tgt_dollarstreet':
                tests += ['shots_1_0.0', 'shots_2_0.0', 'shots_4_0.0', 'shots_6_0.0', 'shots_8_0.0','shots_10_0.0','shots_12_0.0','shots_14_0.0','shots_16_0.0']
        # Loop through relevant test cases 
        for weight_vers in tests:

            # Make sure current path exists 
            path_to_look_at = os.path.join(gen_path, weight_vers + '/' + mode)
            if not os.path.isdir(path_to_look_at):
                continue
            print('\t' + path_to_look_at)
            
            print(path_to_look_at)
            # Add current experiment to dictionary along with placeholders for metrics 
            curr_key = case + '_' + weight_vers + '_' + mode
            dict_case_and_weight_to_data[curr_key] = dict()
            dict_case_and_weight_to_data[curr_key]['F1'] = []
            dict_case_and_weight_to_data[curr_key]['Per-Class Avg Acc'] = []
            dict_case_and_weight_to_data[curr_key]['Overall Acc'] = []

            # Loop through 3 seeds 
            path_to_seed = os.path.join(gen_path, weight_vers + '/' + mode + '/' + MODEL_VERS + '/seed')
            if mode == 'CoCoOp' and case == 'geonet':
                path_to_seed = os.path.join(gen_path, weight_vers + '/' + mode + '/' + 'vit_b16_ep10_ctxv1' + '/seed')
                
            for seed in range(1,4):

                # If not an existing path, ignore 
                if not os.path.isdir(path_to_seed + str(seed)):
                    continue

                # Update seed in dictionary and create log path
                dict_case_and_weight_to_data[curr_key][seed] = dict()
                path_to_log = path_to_seed + str(seed) + '/log.txt'

                # Load current log and parse information
                with open(path_to_log, 'r') as f:
                    lines = f.readlines()
                    for l in lines:
                        if l.startswith('* accuracy'):
                            dict_case_and_weight_to_data[curr_key]['Overall Acc'].append(float(l.strip().split('* accuracy: ')[1].strip('%')))    
                        if l.startswith('* macro_f1'):
                            dict_case_and_weight_to_data[curr_key]['F1'].append(float(l.strip().split('* macro_f1: ')[1].strip('%')))   
                        if l.startswith('* average'):
                            dict_case_and_weight_to_data[curr_key]['Per-Class Avg Acc'].append(float(l.strip().split('* average: ')[1].strip('%')))    
                        if l.startswith('* class'):
                            class_id, class_name, num_correct, total, overall_acc = parse_line(l.strip())
                            dict_case_and_weight_to_data[curr_key][seed][class_name] = overall_acc
# Out:
# dollarstreet_default
# 	/afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/dollarstreet_default/shots_16_0.0/CoOp
# /afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/dollarstreet_default/shots_16_0.0/CoOp
# 	/afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/dollarstreet_default/shots_16_4.0/KgCoOp
# /afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/dollarstreet_default/shots_16_4.0/KgCoOp
# tgt_llm_ensemble_dollarstreet
# 	/afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/tgt_llm_ensemble_dollarstreet/shots_16_4.0/GeoKgCoOp
# /afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/tgt_llm_ensemble_dollarstreet/shots_16_4.0/GeoKgCoOp
# tgt_in_country_ensemble_dollarstreet
# 	/afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/tgt_in_country_ensemble_dollarstreet/shots_16_4.0/GeoKgCoOp
# /afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/tgt_in_country_ensemble_dollarstreet/shots_16_4.0/GeoKgCoOp
# tgt_llm_and_in_country_ensemble_dollarstreet
# 	/afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/tgt_llm_and_in_country_ensemble_dollarstreet/shots_16_4.0/GeoKgCoOp
# /afs/cs.pitt.edu/usr0/krb115/private/soft_prompting/CountryKnowledgePrompting/KgCoOp/output/all/test_all/full_peru_dollarstreet/tgt_llm_and_in_country_ensemble_dollarstreet/shots_16_4.0/GeoKgCoOp

# %% [markdown]
# ### Produce Results for Excel Spreadsheet

# %%
WEIGHT_OF_INTEREST = '4.0'  # which weight value to look at (enter as string like '4.0')
print(dict_case_and_weight_to_data.keys())

files_in_order = [
    'dollarstreet_default_shots_16_0.0_CoOp',
    'dollarstreet_default_shots_16_0.0_CoCoOp',
    'dollarstreet_default_shots_16_' + WEIGHT_OF_INTEREST + '_KgCoOp',
    'tgt_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
    'tgt_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
    'tgt_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
]

#files_in_order = [
#    'am_dollarstreet_default_shots_16_0.0_CoOp',
#    'am_dollarstreet_default_shots_16_0.0_CoCoOp',
#    'am_dollarstreet_default_shots_16_4.0_KgCoOp',
    #'tgt_llm_and_in_country_ensemble_dollarstreet' + '_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'am_tgt_in_country_ensemble_dollarstreet'  + '_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'am_tgt_llm_ensemble_dollarstreet'  + '_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'am_tgt_llm_and_in_country_ensemble_dollarstreet'  + '_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp'  
#]

#files_in_order = [
#    'dollarstreet_default_shots_16_0.0_CoOp',
#    'dollarstreet_default_shots_16_0.0_CoCoOp',
#    'dollarstreet_default_shots_16_8.0_KgCoOp',
#    'dollarstreet_default_shots_16_' + WEIGHT_OF_INTEREST + '_KgCoOp',
#    'src_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'tgt_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'all_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'src_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'tgt_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'all_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'src_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'tgt_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'all_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp'
#]

#files_in_order = [
#    'chat_src_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'chat_tgt_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'chat_all_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'chat_src_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'chat_tgt_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'chat_all_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp'
#]

#files_in_order = [
#    'dollarstreet_default_shots_16_0.0_CoOp',
#    'dollarstreet_default_shots_16_0.0_CoCoOp',
#    'dollarstreet_default_shots_16_8.0_KgCoOp',
#    'dollarstreet_default_shots_16_' + WEIGHT_OF_INTEREST + '_KgCoOp',
#    'am_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'as_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'af_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'am_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'as_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'af_llm_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'am_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'as_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'af_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp'
#]

#files_in_order = [
#    'subset_tgt_dollarstreet_shots_1_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_2_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_4_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_6_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_8_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_10_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_12_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_14_0.0_CoOp',
#    'subset_tgt_dollarstreet_shots_16_0.0_CoOp',
#    'tgt_llm_and_in_country_ensemble_dollarstreet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'dollarstreet_default_shots_16_0.0_CoOp',
#    'dollarstreet_default_shots_16_8.0_KgCoOp',
#    'dollarstreet_default_shots_16_' + WEIGHT_OF_INTEREST + '_KgCoOp',
#]
#files_in_order = [
#    'geonet_shots_16_0.0_CoOp',
#    'geonet_shots_16_0.0_CoCoOp',
#    'geonet_shots_16_8.0_KgCoOp',
#    'geonet_shots_16_' + WEIGHT_OF_INTEREST + '_KgCoOp',                                    
#    'tgt_in_country_ensemble_geonet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',                         
#    'tgt_llm_ensemble_geonet_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp', 
#    'geonet_in_country_llm_desc_shots_16_' + WEIGHT_OF_INTEREST + '_GeoKgCoOp',
#    'geonet_in_country_llm_desc_shots_16_8.0_GeoKgCoOp',
#]
# Out:
# dict_keys(['dollarstreet_default_shots_16_0.0_CoOp', 'dollarstreet_default_shots_16_4.0_KgCoOp', 'tgt_llm_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp', 'tgt_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp', 'tgt_llm_and_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp'])

# %%
# Print results in order of files 
# Leave placeholder value for percent change 
for key in files_in_order:
    if key in dict_case_and_weight_to_data:
        curr_overall_acc_list = dict_case_and_weight_to_data[key]['Overall Acc']
        curr_f1_list = dict_case_and_weight_to_data[key]['F1']
        curr_per_class_acc_list = dict_case_and_weight_to_data[key]['Per-Class Avg Acc']
        print(*([key] + curr_overall_acc_list + [np.mean(curr_overall_acc_list), 0.00] + curr_f1_list
             + [np.mean(curr_f1_list), 0.00] + curr_per_class_acc_list + [np.mean(curr_per_class_acc_list), 0.00]))
# Out:
# dollarstreet_default_shots_16_0.0_CoOp 45.73 42.21 40.2 42.71333333333333 0.0 43.79 36.72 38.35 39.62 0.0 47.1 40.05 41.41 42.85333333333333 0.0
# dollarstreet_default_shots_16_4.0_KgCoOp 44.72 42.21 42.71 43.21333333333334 0.0 42.62 39.14 39.35 40.37 0.0 44.33 40.31 40.46 41.699999999999996 0.0
# tgt_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 44.72 46.73 44.22 45.22333333333333 0.0 40.99 43.39 42.94 42.44 0.0 45.03 46.51 44.41 45.31666666666666 0.0
# tgt_llm_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 44.72 44.72 46.23 45.22333333333333 0.0 42.17 42.46 40.66 41.76333333333333 0.0 44.15 43.87 42.1 43.373333333333335 0.0
# tgt_llm_and_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 44.22 46.23 43.22 44.556666666666665 0.0 42.35 43.81 40.41 42.19 0.0 45.77 45.31 42.54 44.54 0.0

# %% [markdown]
# ### Get Classwise Performance

# %%
# Compute average accuracy for each class 
def get_avg_acc_by_cls_dict(key, dict_case_and_weight_to_data):
    acc_dict = dict()
    for cls_name in dict_case_and_weight_to_data[key][1]:
        acc_1 = dict_case_and_weight_to_data[key][1][cls_name]
        acc_2 = dict_case_and_weight_to_data[key][2][cls_name]
        acc_3 = dict_case_and_weight_to_data[key][3][cls_name]
        avg_acc_for_cls = (acc_1 + acc_2 + acc_3) / 3
        acc_dict[cls_name] = avg_acc_for_cls
    return acc_dict

# Compute what the classes with a default accuracy are 
def get_baseline_classes_lt_threshold_dict(baseline_acc_dict, threshold_list=[0.40, 0.60, 0.80, 1.00]):
    classes_lt_threshold_dict = dict()
    for t in threshold_list:
        classes_lt_threshold_dict[t] = []
        for cls_name in baseline_acc_dict:
            if t == 1.00:
                if baseline_acc_dict[cls_name] <= t:
                    classes_lt_threshold_dict[t].append(cls_name)
            else:
                if baseline_acc_dict[cls_name] < t:
                    classes_lt_threshold_dict[t].append(cls_name)
    return classes_lt_threshold_dict

# Get average accuracy of only the classes lt a threshold - compute over thresholds 
def get_avg_acc_of_classes_lt_threshold(curr_avg_acc_dict, baseline_classes_lt_threshold_dict):
    dict_thresh_to_avg_acc_across_spec_classes = dict()
    for t in baseline_classes_lt_threshold_dict:
        curr_accs = []
        #print(len(baseline_classes_lt_threshold_dict[t]))
        for cls_name in baseline_classes_lt_threshold_dict[t]:
            curr_accs.append(curr_avg_acc_dict[cls_name])
        total_acc = sum(curr_accs)/len(curr_accs)
        dict_thresh_to_avg_acc_across_spec_classes[t] = total_acc
    return dict_thresh_to_avg_acc_across_spec_classes

# %%
BASELINE_MODEL = 'dollarstreet_default_shots_16_0.0_CoOp'
#BASELINE_MODEL = 'geonet_shots_16_0.0_CoOp'

# Get average accuracies and classes 
baseline_acc_dict = get_avg_acc_by_cls_dict(BASELINE_MODEL, dict_case_and_weight_to_data)
baseline_classes_lt_threshold_dict = get_baseline_classes_lt_threshold_dict(baseline_acc_dict)
baseline_acc_dict
# Out:
# {'alarm clocks': 0.5757575757575757,
#  'alcoholic drinks': 0.5833333333333334,
#  'arm watches': 0.9102564102564102,
#  'armchairs': 0.5918367346938775,
#  'backs of a hand': 0.8308457711442786,
#  'beds': 0.8110236220472441,
#  'bikes': 0.935483870967742,
#  'books': 0.6915422885572139,
#  'bowls/plates': 0.49019607843137253,
#  'car keys': 0.7948717948717948,
#  'cars': 0.9629629629629629,
#  'chickens': 0.7777777777777777,
#  'cigarettes': 0.5555555555555555,
#  'cleaning equipment': 0.6060606060606061,
#  'clothes': 0.05555555555555555,
#  'computers': 0.9148936170212766,
#  'contraceptives': 0.7619047619047619,
#  'cooking pots': 0.6904761904761904,
#  'cooking utensils': 0.44897959183673475,
#  'cosmetics': 0.5942028985507246,
#  'couches': 0.7441860465116279,
#  'cups/mugs/glasses': 0.6775956284153005,
#  'cutlery': 0.6347517730496454,
#  'diapers ': 0.6444444444444444,
#  'dish racks': 0.39333333333333337,
#  'dish washing brushes/clothes': 0.6256410256410256,
#  'dish washing soap': 0.5230769230769231,
#  'dishwashers': 0.5952380952380952,
#  'earrings': 0.7948717948717948,
#  'family snapshots': 0.49122807017543857,
#  'freezers': 0.5934959349593496,
#  'front doors': 0.76056338028169,
#  'frontdoor keys': 0.7714285714285715,
#  'frontdoor locks': 0.8358974358974359,
#  'fruit trees': 0.9259259259259259,
#  'fruits/vegetables': 0.7609427609427609,
#  'glasses/lenses': 0.9814814814814815,
#  'grains': 0.6065573770491802,
#  'hair brushes/combs': 0.6046511627906977,
#  'homes': 0.5601374570446734,
#  'instruments': 0.9102564102564102,
#  'jewelry': 0.6666666666666666,
#  'kitchen sinks': 0.6,
#  'light sources': 0.6685288640595903,
#  'makeup': 0.5862068965517242,
#  'meat/fish': 0.8225806451612904,
#  'medication': 0.7701149425287356,
#  'menstruation pads/tampax': 0.7714285714285715,
#  'mopeds/motorcycles': 1.0,
#  'mosquito protections': 0.2982456140350877,
#  'music equipment': 0.4791666666666667,
#  'necklaces': 0.9012345679012346,
#  'ovens': 0.7416666666666667,
#  'palms of a hand': 0.6379928315412187,
#  'paper': 0.775,
#  'pens/pencils': 0.7457627118644069,
#  'pet foods': 0.7037037037037037,
#  'pets': 0.9130434782608695,
#  'phones': 0.6666666666666666,
#  'piercings': 0.48888888888888893,
#  'power outlets': 0.868217054263566,
#  'radios': 0.43333333333333335,
#  'refrigerators': 0.5277777777777777,
#  'roofs': 0.5853658536585366,
#  'rugs': 0.7863247863247862,
#  'salt': 0.658008658008658,
#  'shampoo': 0.6176470588235294,
#  'shoes': 0.7368421052631579,
#  'showers': 0.5931372549019608,
#  'soap for hands and body': 0.4803921568627451,
#  'social drinks': 0.5132275132275131,
#  'spices': 0.5296803652968037,
#  'stoves/hobs': 0.5735294117647058,
#  'tables with food': 0.6759259259259259,
#  'tattoos': 0.9583333333333334,
#  'teeth': 0.8926553672316384,
#  'toilet paper': 0.7777777777777778,
#  'toilets': 0.8062015503875969,
#  'tools': 0.8015873015873015,
#  'toothbrushes': 0.5304659498207885,
#  'toothpaste': 0.6958333333333333,
#  'toys': 0.6666666666666666,
#  'trash/waste': 0.4411764705882353,
#  'tvs': 0.8333333333333334,
#  'wall clocks': 0.8390804597701149,
#  'wall decorations': 0.7417840375586854,
#  'wardrobes': 0.7794117647058822,
#  'washing detergent': 0.582010582010582,
#  'waste dumps': 0.5438596491228069,
#  'water outlets/drains': 0.615819209039548,
#  'wedding photos': 0.8431372549019608,
#  'wheelbarrows': 0.9259259259259259}

# %%
for t in baseline_classes_lt_threshold_dict:
    print(len(baseline_classes_lt_threshold_dict[t]))
# Out:
# 3
# 30
# 69
# 92

# %%
for key in files_in_order:
    if key in dict_case_and_weight_to_data:
        curr_avg_acc_dict = get_avg_acc_by_cls_dict(key, dict_case_and_weight_to_data)
        curr_dict_thresh_to_avg_acc_across_spec_classes = get_avg_acc_of_classes_lt_threshold(curr_avg_acc_dict, baseline_classes_lt_threshold_dict)
        list_of_vals_to_print = []
        for t in curr_dict_thresh_to_avg_acc_across_spec_classes:
            list_of_vals_to_print.append(curr_dict_thresh_to_avg_acc_across_spec_classes[t])
        print(*([key] + list_of_vals_to_print))
# Out:
# dollarstreet_default_shots_16_0.0_CoOp 0.2490448343079922 0.5079463840683567 0.6186410413866661 0.6859846699532532
# dollarstreet_default_shots_16_0.0_CoCoOp 0.3309551656920078 0.5192276550820915 0.6152338399096627 0.6826762941885345
# dollarstreet_default_shots_16_8.0_KgCoOp 0.3719298245614035 0.5357438241307508 0.6233525234714812 0.6826561806161491
# dollarstreet_default_shots_16_4.0_KgCoOp 0.3805847953216374 0.5415071445891988 0.6256826140140636 0.6873161828792478
# src_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.45087719298245604 0.5542630419481168 0.6379495817821107 0.698127161253594
# tgt_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.406588693957115 0.5561244065918988 0.6349418325229463 0.697731781009889
# all_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.40674463937621824 0.5568840971076209 0.6353968856739043 0.6971608405671311
# src_llm_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.39828460038986346 0.5591050363370268 0.6449004716539651 0.703047736544843
# tgt_llm_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.395906432748538 0.5566302157256128 0.6407210937658826 0.7003463743995337
# all_llm_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.40397660818713454 0.5598546047339803 0.6448915758712022 0.7043991110108396
# src_llm_and_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.468187134502924 0.552702240263763 0.6410001389509965 0.7006230261308408
# tgt_llm_and_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.465224171539961 0.5678333774165919 0.6444710339735269 0.7033122708543442
# all_llm_and_in_country_ensemble_dollarstreet_shots_16_4.0_GeoKgCoOp 0.40842105263157896 0.5555727790098588 0.6388597983391912 0.7007670388745586
